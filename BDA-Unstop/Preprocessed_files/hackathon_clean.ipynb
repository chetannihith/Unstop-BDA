# %% [markdown]
# # Import Required Libraries
# Import necessary libraries such as pandas, numpy, and matplotlib.

# %%
# Import Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Display settings for pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Load the Dataset
# Load the raw data file into a pandas DataFrame.

# %%
# Load the Dataset
df = pd.read_csv('../scraped_hackathons.csv')
df.head()
# Out:
#                                             Title  \
# 0                                      Bid By Bit
# 1  CraftNCode (State level for UP and Maharshtra)
# 2                            Datamatics Hackathon
# 3                      SARCathon 2024 - Hackathon
# 4                 Hackathon at Engineer NITK 2024
#
#                                        Organisations  \
# 0                 K.J Somaiya College of Engineering
# 1  International Institute of Information Technol...
# 2       Indian Institute of Technology (IIT), Bombay
# 3       Indian Institute of Technology (IIT), Bombay
# 4  National Institute of Technology Karnataka (NI...
#
#                                                 Link  \
# 0  https://unstop.com/hackathons/bid-by-bit-kj-so...
# 1  https://unstop.com/hackathons/craftncode-state...
# 2  https://unstop.com/hackathons/datamatics-hacka...
# 3  https://unstop.com/hackathons/sarcathon-2024-h...
# 4  https://unstop.com/hackathons/hackathon-at-eng...
#
#                  Uploaded On Opportunity Type Status  Applied  \
# 0  2024-10-08T00:00:00+05:30              NaN   open       16
# 1  2024-10-08T00:00:00+05:30              NaN   open        0
# 2  2024-09-04T00:00:00+05:30              NaN   open       63
# 3  2024-10-08T00:00:00+05:30              NaN   open       39
# 4  2024-10-08T18:00:00+05:30              NaN   open       64
#
#    Application Deadline  Impressions  \
# 0                   2.0         1994
# 1                   9.0         6575
# 2                  21.0         6668
# 3                   2.0         5839
# 4                   5.0         7897
#
#                                          Eligibility  \
# 0  Strategy, Coding Challenge, Hackathon, College...
# 1  Coding Challenge, Hackathon, Engineering Stude...
# 2  Engineering Students, MBA Students, Undergradu...
# 3                   All, Coding Challenge, Hackathon
# 4  Hackathon, Coding Challenge, College Festival,...
#
#                                             Category   Region
# 0  Strategy, Coding Challenge, Hackathon, College...  offline
# 1  Coding Challenge, Hackathon, Engineering Stude...  offline
# 2  Engineering Students, MBA Students, Undergradu...   online
# 3                   All, Coding Challenge, Hackathon   online
# 4  Hackathon, Coding Challenge, College Festival,...  offline

# %% [markdown]
# # Explore the Dataset
# Perform initial exploration of the dataset, including checking the shape, data types, and summary statistics.

# %%
# Explore the Dataset

# Check the shape of the dataset
df.shape

# Check the data types of each column
df.dtypes

# Get summary statistics of the dataset
df.describe(include='all')

# Check for missing values in the dataset
df.isnull().sum()

# Display the first few rows of the dataset
df.head()
# Out:
#                                             Title  \
# 0                                      Bid By Bit
# 1  CraftNCode (State level for UP and Maharshtra)
# 2                            Datamatics Hackathon
# 3                      SARCathon 2024 - Hackathon
# 4                 Hackathon at Engineer NITK 2024
#
#                                        Organisations  \
# 0                 K.J Somaiya College of Engineering
# 1  International Institute of Information Technol...
# 2       Indian Institute of Technology (IIT), Bombay
# 3       Indian Institute of Technology (IIT), Bombay
# 4  National Institute of Technology Karnataka (NI...
#
#                                                 Link  \
# 0  https://unstop.com/hackathons/bid-by-bit-kj-so...
# 1  https://unstop.com/hackathons/craftncode-state...
# 2  https://unstop.com/hackathons/datamatics-hacka...
# 3  https://unstop.com/hackathons/sarcathon-2024-h...
# 4  https://unstop.com/hackathons/hackathon-at-eng...
#
#                  Uploaded On Opportunity Type Status  Applied  \
# 0  2024-10-08T00:00:00+05:30              NaN   open       16
# 1  2024-10-08T00:00:00+05:30              NaN   open        0
# 2  2024-09-04T00:00:00+05:30              NaN   open       63
# 3  2024-10-08T00:00:00+05:30              NaN   open       39
# 4  2024-10-08T18:00:00+05:30              NaN   open       64
#
#    Application Deadline  Impressions  \
# 0                   2.0         1994
# 1                   9.0         6575
# 2                  21.0         6668
# 3                   2.0         5839
# 4                   5.0         7897
#
#                                          Eligibility  \
# 0  Strategy, Coding Challenge, Hackathon, College...
# 1  Coding Challenge, Hackathon, Engineering Stude...
# 2  Engineering Students, MBA Students, Undergradu...
# 3                   All, Coding Challenge, Hackathon
# 4  Hackathon, Coding Challenge, College Festival,...
#
#                                             Category   Region
# 0  Strategy, Coding Challenge, Hackathon, College...  offline
# 1  Coding Challenge, Hackathon, Engineering Stude...  offline
# 2  Engineering Students, MBA Students, Undergradu...   online
# 3                   All, Coding Challenge, Hackathon   online
# 4  Hackathon, Coding Challenge, College Festival,...  offline

# %% [markdown]
# # Handle Missing Values
# Identify and handle missing values in the dataset.

# %%
# Handle Missing Values

# Identify columns with missing values
missing_values = df.isnull().sum()
missing_values = missing_values[missing_values > 0]
missing_values

# Handle missing values by filling with appropriate values or dropping
# For this example, we'll fill missing values with a placeholder or drop them if necessary

# Fill missing values in 'Applied' column with 0 (assuming no applications if missing)
df['Applied'].fillna(0, inplace=True)

# Fill missing values in 'Application Deadline' with a placeholder date
df['Application Deadline'].fillna('2099-12-31', inplace=True)

# Drop rows where 'Link' is missing as it's crucial for identifying the hackathon
df.dropna(subset=['Link'], inplace=True)

# Verify that there are no more missing values
df.isnull().sum()
# Out:
# Title                     0
# Organisations             2
# Link                      0
# Uploaded On               0
# Opportunity Type        132
# Status                    0
# Applied                   0
# Application Deadline      0
# Impressions               0
# Eligibility               0
# Category                  0
# Region                    0
# dtype: int64

# %% [markdown]
# # Convert Data Types
# Convert data types of columns where necessary, such as converting date columns to datetime objects.

# %%
# Convert Data Types

# Convert 'Uploaded On' and 'Application Deadline' columns to datetime objects
df['Uploaded On'] = pd.to_datetime(df['Uploaded On'])
df['Application Deadline'] = pd.to_datetime(df['Application Deadline'])

# Verify the data types after conversion
df.dtypes
# Out:
# Title                                                  object
# Organisations                                          object
# Link                                                   object
# Uploaded On             datetime64[ns, pytz.FixedOffset(330)]
# Opportunity Type                                       object
# Status                                                 object
# Applied                                                 int64
# Application Deadline                           datetime64[ns]
# Impressions                                             int64
# Eligibility                                            object
# Category                                               object
# Region                                                 object
# dtype: object

# %% [markdown]
# # Feature Engineering
# Create new features or modify existing ones to improve the dataset for analysis.

# %%
# Feature Engineering

# Convert 'Uploaded On' and 'Application Deadline' columns to timezone-naive datetime objects
df['Uploaded On'] = pd.to_datetime(df['Uploaded On']).dt.tz_localize(None)
df['Application Deadline'] = pd.to_datetime(df['Application Deadline']).dt.tz_localize(None)

# Create a new feature 'Days Until Deadline' by calculating the difference between 'Application Deadline' and 'Uploaded On'
df['Days Until Deadline'] = (df['Application Deadline'] - df['Uploaded On']).dt.days

# Create a new feature 'Is Online' to indicate if the hackathon is online or offline
df['Is Online'] = df['Region'].apply(lambda x: 1 if x == 'online' else 0)

# Create a new feature 'Total Impressions' by summing up 'Impressions' and 'Applied'
df['Total Impressions'] = df['Impressions'] + df['Applied']

# Create a new feature 'Application Status' to indicate if the application is recent or not
df['Application Status'] = df['Status'].apply(lambda x: 1 if x == 'recent' else 0)

# Display the first few rows to verify the new features
df.head()
# Out:
#                                             Title  \
# 0                                      Bid By Bit
# 1  CraftNCode (State level for UP and Maharshtra)
# 2                            Datamatics Hackathon
# 3                      SARCathon 2024 - Hackathon
# 4                 Hackathon at Engineer NITK 2024
#
#                                        Organisations  \
# 0                 K.J Somaiya College of Engineering
# 1  International Institute of Information Technol...
# 2       Indian Institute of Technology (IIT), Bombay
# 3       Indian Institute of Technology (IIT), Bombay
# 4  National Institute of Technology Karnataka (NI...
#
#                                                 Link         Uploaded On  \
# 0  https://unstop.com/hackathons/bid-by-bit-kj-so... 2024-10-08 00:00:00
# 1  https://unstop.com/hackathons/craftncode-state... 2024-10-08 00:00:00
# 2  https://unstop.com/hackathons/datamatics-hacka... 2024-09-04 00:00:00
# 3  https://unstop.com/hackathons/sarcathon-2024-h... 2024-10-08 00:00:00
# 4  https://unstop.com/hackathons/hackathon-at-eng... 2024-10-08 18:00:00
#
#   Opportunity Type Status  Applied          Application Deadline  Impressions  \
# 0              NaN   open       16 1970-01-01 00:00:00.000000002         1994
# 1              NaN   open        0 1970-01-01 00:00:00.000000009         6575
# 2              NaN   open       63 1970-01-01 00:00:00.000000021         6668
# 3              NaN   open       39 1970-01-01 00:00:00.000000002         5839
# 4              NaN   open       64 1970-01-01 00:00:00.000000005         7897
#
#                                          Eligibility  \
# 0  Strategy, Coding Challenge, Hackathon, College...
# 1  Coding Challenge, Hackathon, Engineering Stude...
# 2  Engineering Students, MBA Students, Undergradu...
# 3                   All, Coding Challenge, Hackathon
# 4  Hackathon, Coding Challenge, College Festival,...
#
#                                             Category   Region  \
# 0  Strategy, Coding Challenge, Hackathon, College...  offline
# 1  Coding Challenge, Hackathon, Engineering Stude...  offline
# 2  Engineering Students, MBA Students, Undergradu...   online
# 3                   All, Coding Challenge, Hackathon   online
# 4  Hackathon, Coding Challenge, College Festival,...  offline
#
#    Days Until Deadline  Is Online  Total Impressions  Application Status
# 0               -20004          0               2010                   0
# 1               -20004          0               6575                   0
# 2               -19970          1               6731                   0
# 3               -20004          1               5878                   0
# 4               -20005          0               7961                   0

# %% [markdown]
# # Save the Cleaned Dataset
# Save the cleaned and preprocessed dataset to a new CSV file.

# %%
# Save the Cleaned Dataset

# Save the cleaned and preprocessed dataset to a new CSV file
df.to_csv('cleaned_hackathons.csv', index=False)
